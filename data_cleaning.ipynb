# %% [markdown]
# # Data Cleaning
# Here are our solutions for automation of filling missing data.<br>
# Main ideology behind this is to train models to recognize patterns like brand, power, etc. in order to classify the correct model (for instance).<br>
# We aim to preserve as much data as we can (minimize deletion of records). We are aware that data produced by models may not be credible so might impact the original idea of predicting prices, however it's the path we want to explore.

# %% [markdown]
# ## Imports and paths

# %%
import pandas as pd
import pathlib as pl
import helper_functions as help_me

# %%
to_fill_path = pl.Path('datasets', '4_filling.csv')

# %% [markdown]
# ## Data loading

# %%
to_fill_df = pd.read_csv(
    filepath_or_buffer=to_fill_path,
    sep=',',
    header=0,
    index_col='ID'
)
to_fill_df.isna().sum()
# Out:
# Cena                     0
# Marka_pojazdu         3274
# Model_pojazdu         3232
# Wersja_pojazdu       48038
# Generacja_pojazdu    41646
# Moc_KM                3732
# Pojemnosc_cm3         4683
# Rodzaj_paliwa         3410
# Naped                13044
# Skrzynia_biegow       3771
# Typ_nadwozia          3358
# Liczba_drzwi          4362
# dtype: int64

# %% [markdown]
# ## Create training dataset & testing datasets
# In this chapter We are focusing on creating datasets (one training and few testing) to predict targets of chosen column.

# %%
training_set = to_fill_df.dropna(
    subset=["Marka_pojazdu", "Model_pojazdu", "Wersja_pojazdu", "Generacja_pojazdu", "Moc_KM", "Pojemnosc_cm3", "Rodzaj_paliwa", "Naped", "Skrzynia_biegow", "Typ_nadwozia", "Liczba_drzwi"]
)
training_set
# Out:
#             Cena  Marka_pojazdu Model_pojazdu                 Wersja_pojazdu  \
# ID
# 2        25900.0        Renault        Megane                    1.6 16V 110
# 4         5999.0           Ford         Focus  1.6 TDCi FX Silver / Silver X
# 8        11900.0        Renault        Scenic            1.5 dCi Authentique
# 10       38900.0           Audi            A4                        2.0 TDI
# 14       38900.0           Audi            A3        1.5 TFSI Sport S tronic
# ...          ...            ...           ...                            ...
# 135375   45900.0           Ford        Mondeo              2.0 TDCi Ambiente
# 135381    3000.0        Citroën         Xsara              II 1.6i Exclusive
# 135385   32500.0           Opel      Insignia             2.8 T V6 Cosmo 4x4
# 135389    2300.0        Peugeot           307                        2.0 HDi
# 135394  269855.0  Mercedes-Benz          Vito            124 CDI Tourer Lang
#
#        Generacja_pojazdu  Moc_KM  Pojemnosc_cm3 Rodzaj_paliwa  \
# ID
# 2        III (2008-2016)   110.0         1598.0      Gasoline
# 4        Mk2 (2004-2011)    90.0         1560.0        Diesel
# 8        III (2009-2013)   105.0         1461.0        Diesel
# 10        B8 (2007-2015)   143.0         1968.0        Diesel
# 14            8V (2012-)   150.0         1498.0      Gasoline
# ...                  ...     ...            ...           ...
# 135375       Mk5 (2014-)   150.0         1997.0        Diesel
# 135381    II (2001-2004)   110.0         1587.0      Gasoline
# 135385     A (2008-2017)   260.0         2792.0      Gasoline
# 135389     I (2001-2005)    90.0         1997.0        Diesel
# 135394      W447 (2014-)   237.0         1950.0        Diesel
#
#                                Naped Skrzynia_biegow   Typ_nadwozia  \
# ID
# 2                       Front wheels          Manual  station_wagon
# 4                       Front wheels          Manual        compact
# 8                       Front wheels          Manual        minivan
# 10                      Front wheels          Manual          sedan
# 14                      Front wheels       Automatic        compact
# ...                              ...             ...            ...
# 135375                  Front wheels          Manual          sedan
# 135381                  Front wheels          Manual        compact
# 135385  4x4 (attached automatically)       Automatic          sedan
# 135389                  Front wheels          Manual      city_cars
# 135394                   Rear wheels       Automatic        minivan
#
#         Liczba_drzwi
# ID
# 2                5.0
# 4                5.0
# 8                5.0
# 10               4.0
# 14               5.0
# ...              ...
# 135375           5.0
# 135381           5.0
# 135385           4.0
# 135389           5.0
# 135394           4.0
#
# [48082 rows x 12 columns]

# %%
brand_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Marka_pojazdu'
)

model_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Model_pojazdu'
)

version_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Wersja_pojazdu'
)

gen_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Generacja_pojazdu'
)

power_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Moc_KM'
)

capacity_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Pojemnosc_cm3'
)

fuel_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Rodzaj_paliwa'
)

drive_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Naped'
)

transmission_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Skrzynia_biegow'
)

body_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Typ_nadwozia'
)

door_testing_set = help_me.create_testing_set(
    df=to_fill_df,
    target_column='Liczba_drzwi'
)

# %%
filled_df = help_me.auto_test(
    training_set=training_set,
    testing_set=model_testing_set
)
# Out:
# DEBUG:helper_functions:Target column: Model_pojazdu, Target type: object
# DEBUG:helper_functions:Classification

# %%
merged_df = pd.merge(
    left=to_fill_df,
    right=filled_df,
    on='ID',
    how='left',
    suffixes=('', '_new')
)

merged_df['Model_pojazdu'] = merged_df['Model_pojazdu'].fillna(value=merged_df['Model_pojazdu_new'])
merged_df.drop(columns='Model_pojazdu_new', axis=1).iloc[130:140]
# Out:
#          Cena   Marka_pojazdu Model_pojazdu               Wersja_pojazdu  \
# ID
# 132   35900.0            Ford        Galaxy                 2.0 TDCi DPF
# 133    4918.0      Volkswagen          Golf                          NaN
# 134   11900.0             BMW       Seria 1                         120d
# 135   79900.0            Ford        Mondeo     2.0 EcoBlue ST-Line Plus
# 136    4899.0      Mitsubishi          Colt               1.5 DID Invite
# 137   43900.0  DS Automobiles           NaN                          NaN
# 138  115000.0           Mazda             6                2.0 SkyEnergy
# 139   92500.0           Mazda             6                          NaN
# 140    8800.0            Opel        Vectra  1.9 CDTI Cosmo ActiveSelect
# 141   12900.0           Volvo           S40                         2.4i
#
#                Generacja_pojazdu  Moc_KM  Pojemnosc_cm3 Rodzaj_paliwa  \
# ID
# 132              Mk2 (2006-2015)   140.0         1998.0        Diesel
# 133               IV (1997-2006)   105.0         1598.0      Gasoline
# 134  E81/E82/E87/E88 (2004-2013)   177.0         1995.0        Diesel
# 135                  Mk5 (2014-)   150.0         1997.0        Diesel
# 136              Z30 (2004-2012)    95.0         1493.0        Diesel
# 137                          NaN   120.0         1600.0        Diesel
# 138                  III (2012-)   165.0         1998.0      Gasoline
# 139                          NaN   253.0         2488.0      Gasoline
# 140                C (2002-2008)   150.0         1910.0        Diesel
# 141               II (2004-2012)   170.0         2435.0      Gasoline
#
#             Naped Skrzynia_biegow   Typ_nadwozia  Liczba_drzwi
# ID
# 132  Front wheels       Automatic        minivan           5.0
# 133  Front wheels          Manual        compact           3.0
# 134   Rear wheels          Manual      city_cars           3.0
# 135  Front wheels          Manual        compact           5.0
# 136  Front wheels          Manual      city_cars           3.0
# 137           NaN             NaN  station_wagon           5.0
# 138  Front wheels       Automatic          sedan           4.0
# 139  Front wheels       Automatic          sedan           5.0
# 140           NaN          Manual  station_wagon           5.0
# 141  Front wheels          Manual          sedan           4.0

# %%
merged_df.isna().sum()
# Out:
# Cena                      0
# Marka_pojazdu          3274
# Model_pojazdu          2008
# Wersja_pojazdu        48038
# Generacja_pojazdu     41646
# Moc_KM                 3732
# Pojemnosc_cm3          4683
# Rodzaj_paliwa          3410
# Naped                 13044
# Skrzynia_biegow        3771
# Typ_nadwozia           3358
# Liczba_drzwi           4362
# Model_pojazdu_new    134096
# dtype: int64
